# %%
# Notebook de Demonstração - Experimento Diabetes

# 1. Clonar o repositório
# !git clone https://github.com/scamilo77/9IADT_TechChallenge_2.git
# %cd 9IADT_TechChallenge_2

# 2. Instalar dependências
# !pip install -r requirements.txt

# 3. Executar experimento de Diabetes
# !python src/DiagnosisTool/optimization/experiments_diabetes.py
